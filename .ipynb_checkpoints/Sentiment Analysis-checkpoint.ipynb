# %%
import pandas as pd
import numpy as np


# misc
import datetime as dt
from pprint import pprint
from itertools import chain
import string
from string import punctuation

# reddit crawler
import praw

# sentiment analysis
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize, RegexpTokenizer # tokenize words
from nltk.corpus import stopwords

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10, 8) # default plot size
import seaborn as sns
sns.set(style='whitegrid', palette='husl')
from wordcloud import WordCloud

# %% [markdown]
# ## Reddit
# Ref: https://medium.com/bitgrit-data-science-publication/sentiment-analysis-on-reddit-tech-news-with-python-cbaddb8e9bb6

# %%
#!pip install praw

# %%
#!pip install wordcloud

# %%
nltk.download('vader_lexicon') # get lexicons data
nltk.download('punkt') # for tokenizer
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\vmartucci\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vmartucci\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vmartucci\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# #### Get data

# %%
f=open("reddit.txt","r")
lines=f.read().split('\n')
username=lines[0]
client_id=lines[1]
client_secret=lines[2]
f.close()

# %%
r = praw.Reddit(user_agent=username,
                client_id=client_id,
                client_secret=client_secret,
                check_for_async=False)

# %%
subreddit = r.subreddit('HousingIreland')

posts = [*subreddit.top(limit=None)] # top posts all time

print(len(posts))
# Out:
# 452

# %%
posts[0]
# Out:
# Submission(id='n5dwmu')

# %%
title = [posts.title for posts in posts]
date_utc = [posts.created_utc for posts in posts]
date = []

import datetime
for d in date_utc:
    x = datetime.datetime.utcfromtimestamp(d).date()
    date.append(x)
    

df = pd.DataFrame({
    "title": title,
    "date": date
})
df.head()
# Out:
#                                                title        date
# 0                Protesting this month is a bad idea  2021-05-05
# 1  There is no reason why the state can't borrow ...  2021-05-20
# 2  Investment advice to global property investors...  2021-05-07
# 3  Barcelona's department of housing can seize em...  2021-05-15
# 4  Ongoing billboard campaign ongoing in r/canada...  2021-05-05

# %%
#get the word count of the post
df["word_count"] = df["title"].apply(lambda x: len(str(x).split()))
df["char_count"] = df["title"].str.len()
df.head()
# Out:
#                                                title        date  word_count  \
# 0                Protesting this month is a bad idea  2021-05-05           7
# 1  There is no reason why the state can't borrow ...  2021-05-20          23
# 2  Investment advice to global property investors...  2021-05-07          21
# 3  Barcelona's department of housing can seize em...  2021-05-15          16
# 4  Ongoing billboard campaign ongoing in r/canada...  2021-05-05           6
#
#    char_count
# 0          35
# 1         124
# 2         149
# 3         110
# 4          53

# %% [markdown]
# #### Sentiment Analysis

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

# %%
def analyze_sentiment(data):
    analysis = SIA().polarity_scores(data)
    if analysis['compound'] > 0:
        return 'Positive'
    elif analysis['compound'] == 0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
df['sentiment'] = df['title'].apply(lambda x : analyze_sentiment(x))

# %%
ax = sns.histplot(df.sentiment, shrink=.8);
ax.bar_label(ax.containers[0]);

# %% [markdown]
# #### Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
text = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for x in df.title: 
      
    # typecaste each val to string 
    x = str(x) 
  
    # split the value 
    values = x.split() 
      
    # Converts each token into lowercase 
    for i in range(len(values)): 
        values[i] = values[i].lower() 
          
    for words in values: 
        text = text + words + ' '


wc = WordCloud(max_words= 50,
               width = 744, 
               height = 544,
               background_color ='white',
               stopwords=stopwords, 
               contour_width=3, 
               contour_color='steelblue',
               min_font_size = 10).generate(text) 
  
# plot the WordCloud image                        
plt.figure(figsize = (14, 14)) 
plt.imshow(wc) 
plt.axis("off")
# Out:
# (-0.5, 743.5, 543.5, -0.5)

# %% [markdown]
# #### Apply text cleaning techniques

# %%
# Load the stop words
#stop = stopwords.words('english')
#df['title'] = df['title'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
# stopwords
# punctuation
# lower case
def text_processing(text):
    stpword = stopwords.words('english')
    no_punctuation = [char for char in text if char not in string.punctuation]
    no_punctuation = ''.join(no_punctuation)
    return ' '.join([word for word in no_punctuation.split() if word.lower() not in stpword])

# %%
df['title processed'] = df['title'].apply(text_processing)
df.head()
# Out:
#                                                title        date  word_count  \
# 0                Protesting this month is a bad idea  2021-05-05           7
# 1  There is no reason why the state can't borrow ...  2021-05-20          23
# 2  Investment advice to global property investors...  2021-05-07          21
# 3  Barcelona's department of housing can seize em...  2021-05-15          16
# 4  Ongoing billboard campaign ongoing in r/canada...  2021-05-05           6
#
#    char_count sentiment                                    title processed
# 0          35  Negative                          Protesting month bad idea
# 1         124  Negative  reason state cant borrow 0 housing instead rel...
# 2         149  Positive  Investment advice global property investors bi...
# 3         110  Negative  Barcelonas department housing seize empty apar...
# 4          53   Neutral  Ongoing billboard campaign ongoing rcanadahousing

# %% [markdown]
# #### Bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english',
                       max_df=.1)
X = count.fit_transform(df['title'].values)
print("X: {}".format(repr(X)))
feature_names = vect.get_feature_names()
print("Number of features: {}".format(len(feature_names)))
print("First 20 features:\n{}".format(feature_names[:20]))
print("Features 100 to 150:\n{}".format(feature_names[100:150]))
print("Features 160 to 194:\n{}".format(feature_names[160:194]))
# Out:
# X: <452x1646 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3173 stored elements in Compressed Sparse Row format>
# Number of features: 194
# First 20 features:
# ['000', '10', '12', 'about', 'across', 'action', 'actually', 'advice', 'affordable', 'after', 'against', 'ago', 'all', 'also', 'an', 'and', 'another', 'any', 'anyone', 'apartment']
# Features 100 to 150:
# ['local', 'long', 'looking', 'low', 'make', 'many', 'market', 'minister', 'money', 'more', 'mortgage', 'most', 'my', 'national', 'need', 'needed', 'new', 'no', 'not', 'now', 'of', 'on', 'one', 'only', 'or', 'our', 'out', 'over', 'people', 'place', 'policy', 'post', 'pressure', 'price', 'prices', 'properties', 'property', 'protest', 'public', 're', 'reits', 'rent', 'rental', 'renting', 'rents', 'report', 'right', 'rory', 'rules', 'says']
# Features 160 to 194:
# ['tax', 'td', 'tds', 'than', 'that', 'the', 'their', 'them', 'there', 'these', 'they', 'this', 'thought', 'time', 'to', 'too', 'up', 'update', 'vacant', 'vulture', 'was', 'we', 'what', 'which', 'while', 'who', 'why', 'will', 'with', 'would', 'year', 'years', 'you', 'your']

# %% [markdown]
# #### Latent Dirichlet Allocation (top topics)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation(n_components=5,
                               random_state=123,
                               learning_method='batch')
X_topics = lda.fit_transform(X)

# %%
n_top_words=5
feature_names = count.get_feature_names()
for topic_id, topic in enumerate(lda.components_):
    print("Topic %d:" % (topic_id + 1))
    print(" ".join([feature_names[i]
                   for i in topic.argsort()\
                    [:-n_top_words - 1:-1]]))
# Out:
# Topic 1:
# irish market investment funds homes
# Topic 2:
# crisis funds time ireland new
# Topic 3:
# rent dublin ireland house new
# Topic 4:
# house ireland protest prices government
# Topic 5:
# homes new crisis government rent

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# we have our X from Bag of wods, let's create the same one for the processed text
X_proc = count.fit_transform(df['title processed'].values)

# y to numeric
mapping = {'Positive': 1, 'Negative': -1, 'Neutral': 0}
sentiments = df['sentiment'].values
y = [mapping[s] for s in sentiments]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0) # 67% training and 33% test
X_train.shape, X_test.shape
# Out:
# ((302, 1646), (150, 1646))

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
scores = cross_val_score(LogisticRegression(), X_train, y_train, cv=5)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))
# Out:
# Mean cross-validation accuracy: 0.58

# %% [markdown]
# Let's see if there's any difference using the processed text

# %%
X_train, X_test, y_train, y_test = train_test_split(X_proc, y, test_size=0.33, random_state=0) # 67% training and 33% test // found out by 1 - test_size = 1 - 0.33 = 0.67 -> 67%

# %%
scores = cross_val_score(LogisticRegression(), X_train, y_train, cv=5)
print("Mean cross-validation accuracy: {:.2f}".format(np.mean(scores)))
# Out:
# Mean cross-validation accuracy: 0.55

# %% [markdown]
# Interestingly, the accuracy seems not to improve, but actually decreased by 0.01pt, let's tune the <i>LogisticRegression</i> via cross-validation to find the best paramaters across different training/testing size:

# %%
# let's get original title back as it performed better
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
for i in np.arange(0.2, 0.5, 0.05):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=i, random_state=0)
    grid.fit(X_train, y_train)
    print("Values for train_size= ",i)
    print("Best cross-validation score: {:.2f}".format(grid.best_score_))
    print("Best parameters: ", grid.best_params_)
    print("Test score: {:.2f}".format(grid.score(X_test, y_test)))
    print("-----")
# Out:
# Values for train_size=  0.2
# Best cross-validation score: 0.57
# Best parameters:  {'C': 1}
# Test score: 0.52
# -----
# Values for train_size=  0.25
# Best cross-validation score: 0.59
# Best parameters:  {'C': 1}
# Test score: 0.55
# -----
# Values for train_size=  0.3
# Best cross-validation score: 0.57
# Best parameters:  {'C': 15}
# Test score: 0.52
# -----
# Values for train_size=  0.35
# Best cross-validation score: 0.60
# Best parameters:  {'C': 20}
# Test score: 0.54
# -----
# Values for train_size=  0.39999999999999997
# Best cross-validation score: 0.56
# Best parameters:  {'C': 20}
# Test score: 0.52
# -----
# Values for train_size=  0.44999999999999996
# Best cross-validation score: 0.57
# Best parameters:  {'C': 15}
# Test score: 0.53
# -----

# %% [markdown]
# #### Classification using TF-ID vectorizer and Gaussian Naive-Bayes

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer =  TfidfVectorizer(analyzer = stemmed_words, max_features = 1000)
feature_vector =  tfidf_vectorizer.fit(train_data.Text)
train_ds_features = tfidf_vectorizer.transform(train_data.Text)
features = feature_vector.get_feature_names()
